# %%
#################################################
#Prac 06 file 3 - COMP1050
#################################################

#Scipy for Sensor Data Filtering and matplotlib For Sensor Data plotting


# Go down to the bottom of this file. We have 2 team "challenges" for you to complete

# In this file we are getting you to use Python to complete a combination of filtering and plotting
#for sensor data in the practical project

# %%
# Based on the given sample data, 
# import packages
import numpy as np
import pandas as pd
import math

#code snippet 1
df = pd.read_csv('dataset_1.txt', sep=',', header=None)  # use pandas to read sensor data file
print('The dataset contains %d rows.' % len(df))
# Out:
# The dataset contains 245576 rows.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df_sitting = df[df[24] == 1].values
df_lying = df[df[24] == 2].values
df_standing = df[df[24] == 3].values
df_washingDishes = df[df[24] == 4].values
df_vacuuming = df[df[24] == 5].values
df_sweeping = df[df[24] == 6].values
df_walking = df[df[24] == 7].values
df_ascStairs = df[df[24] == 8].values
df_desStairs = df[df[24] == 9].values
df_treRunning = df[df[24] == 10].values
df_bicycle50 = df[df[24] == 11].values
df_bicycle100 = df[df[24] == 12].values
df_ropeJumping = df[df[24] == 13].values

# %%
# Sensor data filtering. Scipy libary
#code snippet 4
from scipy import signal

#b, a = signal.butter(4, 0.04, 'lowpass', analog=False)
#for i in range(3):
  #  df_sitting[:,i] = signal.lfilter(b, a, df_sitting[:, i])
#plt.plot(df_sitting[500:1500, 0:3])

# %%
#################################################
#Challenge - 1
#################################################
#TODO:
#1. Based on the code snippet 4, add your code to 
# clean all the sensor data for activities in the given dataset#Hint: you might need to add another outside loop

for activity in range(1,14):
    df_activity = df[df[24] == activity].values
    
    b, a = signal.butter(4, 0.04, 'low', analog=False)
    for i in range(24):
        df_activity[:, i] = signal.lfilter(b, a, df_activity[:, i])

plt.plot(df_sitting[500:1500, 0:3])

#plt.plot(df_sitting[500:1500, 0:3])
#plt.plot(df_sitting[500:1500, 3:6])
#plt.plot(df_sitting[500:1500, 6:9])
#plt.plot(df_sitting[500:1500, 9:12])
#plt.plot(df_sitting[500:1500, 12:15])
#plt.plot(df_sitting[500:1500, 15:18])
#plt.plot(df_sitting[500:1500, 18:21])
#plt.plot(df_sitting[500:1500, 21:24])


#TODO: add your other code in here .   <<<-------------
# Out:
# [<matplotlib.lines.Line2D at 0x1cc2aba0fc8>,
#  <matplotlib.lines.Line2D at 0x1cc2abaa288>,
#  <matplotlib.lines.Line2D at 0x1cc2abaa448>]

# %%
#################################################
#Challenge - 2
#################################################
#TODO:
#1. Based on the challenge 1, add your code to 
#  plot the first sensor data in the first sensor device for the Washing dishes activity 
# to check whether your solution for Challenge 1 is working

plt.plot(df_washingDishes[500:1500, 0:3])

#TODO: add your other code in here .   <<<-------------
# Out:
# [<matplotlib.lines.Line2D at 0x1cc2aabee48>,
#  <matplotlib.lines.Line2D at 0x1cc2aac99c8>,
#  <matplotlib.lines.Line2D at 0x1cc2aac9b88>]
